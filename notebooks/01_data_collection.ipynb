# %% [markdown]
# # 01 — Data Collection
# Wire Kalshi + BTC data APIs here; save snapshots to `data/raw/`.

# %%
from src.kalshi_proj.fetch_data import fetch_kalshi_markets, fetch_btc_timeseries
raw_markets = fetch_kalshi_markets()
btc_df = fetch_btc_timeseries()
print('rows:', len(raw_markets), len(btc_df))
